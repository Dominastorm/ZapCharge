# %%
import folium
import pandas as pd
import math
import random
import numpy as np
from haversine import haversine

# %%
def generate_coordinates_within_distance(latitude, longitude, distance):
    # Convert distance from meters to kilometers
    distance_km = random.uniform(0, distance) / 1000.0

    # Convert latitude and longitude to radians
    lat_rad = math.radians(latitude)
    lon_rad = math.radians(longitude)

    # Calculate a random bearing (in radians)
    random_bearing = random.uniform(0, 2 * math.pi)

    # Calculate the maximum angular distance (in radians) for generating coordinates
    max_angular_distance = distance_km / 6371.0

    # Calculate the new latitude
    new_lat_rad = math.asin(math.sin(lat_rad) * math.cos(max_angular_distance) + math.cos(lat_rad) * math.sin(max_angular_distance) * math.cos(random_bearing))

    # Calculate the new longitude
    new_lon_rad = lon_rad + math.atan2(math.sin(random_bearing) * math.sin(max_angular_distance) * math.cos(lat_rad), math.cos(max_angular_distance) - math.sin(lat_rad) * math.sin(new_lat_rad))

    # Convert the new latitude and longitude back to degrees
    new_latitude = math.degrees(new_lat_rad)
    new_longitude = math.degrees(new_lon_rad)

    return new_latitude, new_longitude

# %%
def generate_data(L, distance_meters, iterations):
    for given_latitude, given_longitude in L:
        for _ in range(iterations):
            generated_latitude, generated_longitude = generate_coordinates_within_distance(given_latitude, given_longitude, distance_meters)
            print(round(generated_latitude, 5), round(generated_longitude, 5), file=open("../../data/data_1.txt", "a"))

# %%
L = [(12.891442, 77.576690), (12.883189, 77.582958), (12.880897, 77.595722), (12.894222, 77.598295)]
distance_meters = 2000
iterations = 50

generate_data(L, distance_meters, iterations)

# %%
with open('../../data/data_1.txt', 'r') as file:
    L = []
    for line in file:
        if line and line != '\n':
            L.append([float(x) for x in line.strip().split(' ')])

# %%
column_names = ['latitude', 'longitude']
df = pd.DataFrame(L, columns=[column_names])
df.to_csv('../../data/data_1.csv', mode='a', index=False, header=False)

# %%
df = pd.read_csv('../../data/data_1.csv')
coordinates = df.values.tolist()

# %%
city_coords = (12.938655, 77.581057)
colors = ['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'beige', 'darkblue', 'darkgreen', 'cadetblue', 'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen', 'black']
n = len(colors)

# %%
map = folium.Map(location=city_coords, zoom_start=15, control_scale = True)
for latitude, longitude in coordinates:
    folium.Marker(location=(latitude, longitude), icon=folium.Icon()).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_837e61d887e5c0543811a200c4a6f4db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_837e61d887e5c0543811a200c4a6f4db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_837e61d887e5c0543811a200c4a6f4db = L.map(
#                 &quot;map_837e61d887e5c0543811a200c4a6f4db&quot;,
#                 {
#                     center: [12.938655, 77.581057],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_837e61d887e5c0543811a200c4a6f4db);
#
#
#
#
#
#             var tile_layer_b24427efe318e423a6ad86f8c8120f8e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_837e61d887e5c0543811a200c4a6f4db);
#
#
#             var marker_da284ab397beeee43b4684d4d7d37c71 = L.marker(
#                 [12.90116, 77.58816],
#                 {}
#             ).addTo(map_837e61d887e5c0543811a200c4a6f4db);
#
#
#             var icon_04265b1c38d3060c00d2889ed85482d6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_da284ab397beeee43b4684d4d7d37c71.setIcon(icon_04265b1c38d3060c00d2889ed85482d6);
#
#
#             var marker_937ec9779b4dc608f5e935339db99e7a = L.marker(
#                 [12.88838, 77.57912],
#                 {}
#             ).addTo(map_837e61d887e5c0543811a200c4a6f4db);
#
#
#             var icon_8344ef511d0cdd3644727b7b970a600a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_937ec9779b4dc608f5e935339db99e7a.setIcon(icon_8344ef511d0cdd3644727b7b970a600a);
#
#
#             var marker_bf97931e35166b9405c5607c007014c8 = L.marker(
#                 [12.89651, 77.58472],
#                 {}
#             ).addTo(map_837e61d887e5c0543811a200c4a6f4db);
#
#
#             var icon_97220fef44b6de8332231dc21af23f40 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bf97931e35166b9405c5607c007014c8.setIcon(icon_97220fef44b6de8332231dc21af23f40);
#
#
#             var marker_9a3abc58507e7c85824728d22e906b0b = L.marker(
#                 [12.88731, 77.57957],
#                 {}
#             ).addTo(map_837e61d887e5c0543811a200c4a6f4db);
#
#
#             var icon_2022d993a6f46d84f4ac76c6667e50f2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9a3abc58507e7c85824728d22e906b0b.setIcon(icon_2022d993a6f46d84f4ac76c6667e50f2);
#
#
#             var marker_16b7ec2fb527d399733c6ca5c5f3a263 = L.marker(
#                 [12.90417, 77.56756],
#                 {}
#             ).addTo(map_837e61d887e5c0543811a200c4a6f4db);
#
#
#             var icon_39035b2e39c8c9fd426f3f32bf776db7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_16b7ec2fb527d399733c6ca5c5f3a263.setIcon(icon_39035b2e39c8c9fd426f3f32bf776db7);
#
#
#             var marker_d96cb8303c0e65d4a0089bcd1cb2b54d = L.marker(
#                 [12.89121, 77.57616],
#                 {}
#             ).addTo(map_837e61d887e5c0543811a200c4a6f4db);
#
#
#             var icon_0f996f1c46385bf61fea84bd4462e4fc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d96cb8303c0e65d4a0089bcd1cb2b54d.setIcon(icon_0f996f1c46385bf61fea84bd4462e4fc);
#
#
#             var marker_6f64c9be458b76aa9b5c16c7ed145496 = L.marker(
#                 [12.8971, 77.58657],
#                 {}
#             ).addTo(map_837

# %%
def cluster_by_distance(points, radius):
    distances = []
    n = len(points)
    for i in range(n):
        distances.append([])
        for j in range(i + 1, n):
            distances[-1].append(haversine(points[i], points[j])) #unit is km

    # visited = [0]*n
    clusters = []
    for i in range(n):
        clusters.append([])
        count = 0
        for d in distances[i]:
            count += 1
            if d <= radius:
                clusters[-1].append(points[i+count])

    return clusters

# %%
radius, min_samples = 0.2, 15
clusters_1 = [x for x in cluster_by_distance(coordinates.copy(), radius) if len(x) >= min_samples]
map1 = folium.Map(location=city_coords, zoom_start=10)
for i in range(len(clusters_1)):
    cluster = clusters_1[i]
    color = colors[i % n]
    for point in cluster:
        x, y = point[0], point[1]
        folium.Marker(location= (x, y), icon=folium.Icon(color=color)).add_to(map1)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_837e61d887e5c0543811a200c4a6f4db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_837e61d887e5c0543811a200c4a6f4db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_837e61d887e5c0543811a200c4a6f4db = L.map(
#                 &quot;map_837e61d887e5c0543811a200c4a6f4db&quot;,
#                 {
#                     center: [12.938655, 77.581057],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_837e61d887e5c0543811a200c4a6f4db);
#
#
#
#
#
#             var tile_layer_b24427efe318e423a6ad86f8c8120f8e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_837e61d887e5c0543811a200c4a6f4db);
#
#
#             var marker_da284ab397beeee43b4684d4d7d37c71 = L.marker(
#                 [12.90116, 77.58816],
#                 {}
#             ).addTo(map_837e61d887e5c0543811a200c4a6f4db);
#
#
#             var icon_04265b1c38d3060c00d2889ed85482d6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_da284ab397beeee43b4684d4d7d37c71.setIcon(icon_04265b1c38d3060c00d2889ed85482d6);
#
#
#             var marker_937ec9779b4dc608f5e935339db99e7a = L.marker(
#                 [12.88838, 77.57912],
#                 {}
#             ).addTo(map_837e61d887e5c0543811a200c4a6f4db);
#
#
#             var icon_8344ef511d0cdd3644727b7b970a600a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_937ec9779b4dc608f5e935339db99e7a.setIcon(icon_8344ef511d0cdd3644727b7b970a600a);
#
#
#             var marker_bf97931e35166b9405c5607c007014c8 = L.marker(
#                 [12.89651, 77.58472],
#                 {}
#             ).addTo(map_837e61d887e5c0543811a200c4a6f4db);
#
#
#             var icon_97220fef44b6de8332231dc21af23f40 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bf97931e35166b9405c5607c007014c8.setIcon(icon_97220fef44b6de8332231dc21af23f40);
#
#
#             var marker_9a3abc58507e7c85824728d22e906b0b = L.marker(
#                 [12.88731, 77.57957],
#                 {}
#             ).addTo(map_837e61d887e5c0543811a200c4a6f4db);
#
#
#             var icon_2022d993a6f46d84f4ac76c6667e50f2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9a3abc58507e7c85824728d22e906b0b.setIcon(icon_2022d993a6f46d84f4ac76c6667e50f2);
#
#
#             var marker_16b7ec2fb527d399733c6ca5c5f3a263 = L.marker(
#                 [12.90417, 77.56756],
#                 {}
#             ).addTo(map_837e61d887e5c0543811a200c4a6f4db);
#
#
#             var icon_39035b2e39c8c9fd426f3f32bf776db7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_16b7ec2fb527d399733c6ca5c5f3a263.setIcon(icon_39035b2e39c8c9fd426f3f32bf776db7);
#
#
#             var marker_d96cb8303c0e65d4a0089bcd1cb2b54d = L.marker(
#                 [12.89121, 77.57616],
#                 {}
#             ).addTo(map_837e61d887e5c0543811a200c4a6f4db);
#
#
#             var icon_0f996f1c46385bf61fea84bd4462e4fc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d96cb8303c0e65d4a0089bcd1cb2b54d.setIcon(icon_0f996f1c46385bf61fea84bd4462e4fc);
#
#
#             var marker_6f64c9be458b76aa9b5c16c7ed145496 = L.marker(
#                 [12.8971, 77.58657],
#                 {}
#             ).addTo(map_837

# %%
#https://geoffboeing.com/2014/08/clustering-to-reduce-spatial-data-set-size/

# %%
from sklearn.cluster import DBSCAN

# %%
epsilon = 0.5 / 6371.0
min_samples = 15
db = DBSCAN(eps=epsilon, min_samples=min_samples, algorithm='ball_tree', metric='haversine').fit(np.radians(df.to_numpy()))
labels = db.labels_
map2 = folium.Map(location=city_coords, zoom_start=15, control_scale = True)
for i in range(len(labels)):
    if labels[i] == -1:
        color = 'gray'
        folium.Marker(location= coordinates[i], icon=folium.Icon(color=color)).add_to(map2)

    else:
        color = colors[labels[i] % n]
        folium.Marker(location= coordinates[i], icon=folium.Icon(color=color)).add_to(map2)
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d23eea006dbe7e82b8ebd67f0598f63 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d23eea006dbe7e82b8ebd67f0598f63&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d23eea006dbe7e82b8ebd67f0598f63 = L.map(
#                 &quot;map_6d23eea006dbe7e82b8ebd67f0598f63&quot;,
#                 {
#                     center: [12.938655, 77.581057],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_6d23eea006dbe7e82b8ebd67f0598f63);
#
#
#
#
#
#             var tile_layer_28f2297dd65285fc7c02fe8dae3da6ec = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6d23eea006dbe7e82b8ebd67f0598f63);
#
#
#             var marker_aa8bec64f6327a91f69248a0f23007f6 = L.marker(
#                 [12.90116, 77.58816],
#                 {}
#             ).addTo(map_6d23eea006dbe7e82b8ebd67f0598f63);
#
#
#             var icon_c2b986a5914d9f687693fd79a2b8031a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_aa8bec64f6327a91f69248a0f23007f6.setIcon(icon_c2b986a5914d9f687693fd79a2b8031a);
#
#
#             var marker_9c89ade9790596ddbb2847df2a38824e = L.marker(
#                 [12.88838, 77.57912],
#                 {}
#             ).addTo(map_6d23eea006dbe7e82b8ebd67f0598f63);
#
#
#             var icon_5e2235a15c483e2f4f059311d32805cf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9c89ade9790596ddbb2847df2a38824e.setIcon(icon_5e2235a15c483e2f4f059311d32805cf);
#
#
#             var marker_61581a538f096d4ff8445c649d2960ae = L.marker(
#                 [12.89651, 77.58472],
#                 {}
#             ).addTo(map_6d23eea006dbe7e82b8ebd67f0598f63);
#
#
#             var icon_efc62fc95061be4c05f48ce5e7366f82 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_61581a538f096d4ff8445c649d2960ae.setIcon(icon_efc62fc95061be4c05f48ce5e7366f82);
#
#
#             var marker_b4ad684e9b181fb55316c24f3c2dcc4a = L.marker(
#                 [12.88731, 77.57957],
#                 {}
#             ).addTo(map_6d23eea006dbe7e82b8ebd67f0598f63);
#
#
#             var icon_b8949458dc66f47cb789fba02c700fe7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b4ad684e9b181fb55316c24f3c2dcc4a.setIcon(icon_b8949458dc66f47cb789fba02c700fe7);
#
#
#             var marker_d4398d7be3f338ccbfaddf372638d176 = L.marker(
#                 [12.90417, 77.56756],
#                 {}
#             ).addTo(map_6d23eea006dbe7e82b8ebd67f0598f63);
#
#
#             var icon_151730884cd4bb0117f026ebceec3a13 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d4398d7be3f338ccbfaddf372638d176.setIcon(icon_151730884cd4bb0117f026ebceec3a13);
#
#
#             var marker_de3e4fee2909400a30d7ac789e203f15 = L.marker(
#                 [12.89121, 77.57616],
#                 {}
#             ).addTo(map_6d23eea006dbe7e82b8ebd67f0598f63);
#
#
#             var icon_bd28c11084ec8513c7e55a93fb0fa353 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_de3e4fee2909400a30d7ac789e203f15.setIcon(icon_bd28c11084ec8513c7e55a93fb0fa353);
#
#
#             var marker_97bf6f010f19bacdbfaf01d71e6d8b06 = L.marker(
#                 [12.8971, 77.58657],
#                 {}
#             ).addTo(map_6d23eea0
